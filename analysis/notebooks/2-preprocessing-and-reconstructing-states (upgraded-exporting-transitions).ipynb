# %%
import copy
import pickle

import pathlib as pl
import pandas as pd
import networkx as nx

from justhink_world import create_all_worlds
from justhink_world.domain.state import NetworkState, EnvironmentState
from justhink_world.agent import Human, Robot
from justhink_world.domain.action import *

# %%
pd.set_option('display.max_rows', 500)

action_type_dict = {
    'TYPE_SUGGEST_PICK': 0,
    'TYPE_PICK': 1,
    'TYPE_UNPICK': 2,
    'TYPE_SUBMIT': 3,
    'TYPE_SUGGEST_SUBMIT': 4,
    'TYPE_CLEAR_SUGGEST_SUBMIT': 5,
    'TYPE_AGREE': 6,
    'TYPE_DISAGREE': 7,
    'TYPE_CLEAR': 8,
    'TYPE_GUESS': 9}

# %% [markdown]
# # Define paths.

# %%
resources_dir = pl.Path('resources')
networks_dir = resources_dir.joinpath('networks')
tables_dir = pl.Path('../processed_data/log_tables')

processed_tables_pickle_file = pl.Path(
    '../processed_data/processed_tables.pickle')
transitions_pickle_file = pl.Path('../processed_data/justhink_spring21_transition_logs.pickle')

# %% [markdown]
# # Initializing Problems.

# %%
worlds = create_all_worlds()

# %%
name = 'pretest-1'
name = 'collab-activity-1'

worlds[name].env.state.network.graph.edges(data=True), worlds[name].env.state.network.subgraph.edges(data=True)
# Out:
# (EdgeDataView([(3, 1, {'cost': 3}), (3, 0, {'cost': 3}), (3, 2, {'cost': 3}), (3, 5, {'cost': 4}), (3, 7, {'cost': 5}), (1, 9, {'cost': 3}), (1, 2, {'cost': 2}), (1, 5, {'cost': 4}), (1, 4, {'cost': 3}), (0, 2, {'cost': 5}), (0, 7, {'cost': 4}), (2, 9, {'cost': 4}), (2, 8, {'cost': 3}), (5, 4, {'cost': 2}), (5, 7, {'cost': 3}), (5, 6, {'cost': 4}), (4, 9, {'cost': 3}), (4, 6, {'cost': 2}), (7, 6, {'cost': 2}), (9, 8, {'cost': 2})]),
#  EdgeDataView([]))

# %%
world_renamer = {name: name for name in worlds} 
world_renamer['indiv-illustrate'] = 'demo'
world_renamer['collab-activity'] = 'collab-activity-1'

# %% [markdown]
# # Make dictionaries for dataframe traversal.

# %%
# dictionary for file path, key is student id
file_list = tables_dir.glob(
    'justhink20_log_*/justhink_app-state_transition.csv')
files = {}

for f in file_list:
    i = int(str(f.parent).split('_')[-1])
    files[i] = f

# dictionary for the state transition tables, key is student id
tables = {}

for student in files:
    df = pd.read_csv(files[student])
    tables[student] = df

# %%
tables[1].columns
# Out:
# Index(['Time', 'header.seq', 'header.frame_id', 'state.edges',
#        'state.suggested.u', 'state.suggested.v', 'state.terminal',
#        'state.submit_suggested', 'action.agent_name', 'action.type',
#        'action.edge.u', 'action.edge.v', 'next_state.edges',
#        'next_state.suggested.u', 'next_state.suggested.v',
#        'next_state.terminal', 'next_state.submit_suggested', 'action_no',
#        'step_no', 'turn_agent'],
#       dtype='object')

# %% [markdown]
# # Reconstruct a State.

# %%
# reconstructing the state of the input row
def reconstruct_state(row, graph, state_name='state', verbose=False):
    # row_index refers to table row +2
    #     row = full_row[3:9]
    #     print(row)

    # reconstructs edge list from string
    edge_list_text = str(row['{}.edges'.format(state_name)])
    edge_list = edge_list_text.strip('[').strip(']').split(',')
    edges = list()
    for edge_text in edge_list:
        # if the edge list is empty
        if edge_list[0] == '':
            break
        l = edge_text.split()
        edge = (int(l[1]), int(l[3]))
        edges.append(edge)
    # edges = frozenset(edges)
    subgraph = nx.Graph()
    for u, v in edges:
        subgraph.add_edge(u, v)

    suggested_edge = (int(row['{}.suggested.u'.format(state_name)]),
                      int(row['{}.suggested.v'.format(state_name)]))
    if suggested_edge == (-1, -1):
        suggested_edge = None

    is_terminal = bool(row['{}.terminal'.format(state_name)])
    is_submitting = bool(row['{}.submit_suggested'.format(state_name)])

    if row['turn_agent'] == 'human':
        agents = frozenset({Human})
    elif row['turn_agent'] == 'robot':
        agents = frozenset({Robot})
    else:
        agents = frozenset()

    network = NetworkState(graph, subgraph, suggested_edge)
    state = EnvironmentState(
        network, agents=agents, is_submitting=is_submitting, is_terminal=is_terminal)

    if verbose:
        print(state)
    return state

# %%
world = worlds['pretest-1']
df = tables[1].copy()
row_index = 10
reconstruct_state(df.iloc[row_index], world.env.state.network.graph, verbose=True)
# Out:
# EnvironmentState(NetworkState(e:6+0,c:19|n:7,e:12;s:0)@1/inf,a:H;p:0,t:0,s:0,h:0)
# EnvironmentState(NetworkState(e:6+0,c:19|n:7,e:12;s:0)@1/inf,a:H;p:0,t:0,s:0,h:0)

# %% [markdown]
# # Reconstruct an Action object.

# %%
# reconstructing action objects by action type
def reconstruct_action(row, graph, verbose=False):
    action_type = row['action.type']
    if row['action.agent_name'] == 'human':
        agent = Human
    elif row['action.agent_name'] == 'robot':
        agent = Robot
    else:
        raise NotImplementedError
        
    if action_type == 0:
        return SuggestPickAction((row['action.edge.u'], row['action.edge.v']), agent)
    if action_type == 1:
        return PickAction((row['action.edge.u'], row['action.edge.v']), agent)
    if action_type == 2:
        return UnpickAction((row['action.edge.u'], row['action.edge.v']), agent)
    if action_type == 3:
        return SubmitAction(agent)
    if action_type == 4:
        # return SuggestSubmitAction(agent)
        return AttemptSubmitAction(agent)
    if action_type == 5:
        # return ClearSuggestSubmitAction(agent)
        return ContinueAction(agent)
    if action_type == 6:
        return AgreeAction(agent)
    if action_type == 7:
        return DisagreeAction(agent)
    if action_type == 8:
        return ClearAction()
    if action_type == 9:
        print("TYPE_GUESS")
    return None

# %%
world = worlds['pretest-1']
df = tables[1].copy()
row_index = 10
reconstruct_action(df.iloc[row_index], world.env.state.network.graph, verbose=True)
# Out:
# Action(pick(5,6),Human)

# %% [markdown]
# # Reconstruct all States and Action objects.
#
# Appending world_state, action, is_submission, cost, and is_mst columns to the table.

# %%
# reconstruct the state for every row in the table
def construct_state_from_table(df, state_name='state', verbose=False):
    state_list = []
    is_submission = []
    cost = []
    is_mst = []
    action_list = []

    attempt_nos = dict()
    for i, row in df.iterrows():
        problem_name = row['header.frame_id']
        # Renamed scenes.
        problem_name = world_renamer[problem_name]
        problem = worlds[problem_name]
        
        if problem_name not in attempt_nos:
            attempt_nos[problem_name] = 1
        
        action = reconstruct_action(row, problem.env.state.network.graph)
        action_list.append(action)

        
        state = reconstruct_state(
            row, problem.env.state.network.graph, state_name=state_name)

        submission = identify_submission_state(row)
        is_submission.append(submission)
        if verbose and submission:
            print('Submitted', problem_name, state)

        # Update the attempt number.
        if submission:
            attempt_nos[problem_name] = attempt_nos[problem_name] + 1
        state.attempt_no = attempt_nos[problem_name]

        # Update the max attempts.
        if 'collab-activity' in problem_name:
            state.max_attempts = 4
            
        state_list.append(state)

        cost.append(state.network.get_cost())
        is_mst.append(state.network.is_mst())

    # append worldstate column
    df[state_name] = state_list
    # append action object column
    df['action'] = action_list
    # append is submission column
    df['is_submission'] = is_submission
    # append cost column
    df['cost'] = cost
    # append is_mst column
    df['is_mst'] = is_mst

    return df

# %% [markdown]
# ### Identifying submission state.

# %%
# identifies which problem state has been submitted
def identify_submission_state(row):
    # check if the last state's action type is submit type 3 or 4
    problem_name = row['header.frame_id']
    
    # Renamed scenes.
    problem_name = world_renamer[problem_name]
        
    action_type = row['action.type']

    if 'test' in problem_name:
        return action_type == 4

    # for collaborative activities check for 3 only
    elif "collab" in problem_name:
        return action_type == 3

    else:
        return False

# %%
name = 'collab-activity'
name = 'pretest-1'
df = tables[1].copy()
df = construct_state_from_table(df, state_name='next_state')
df = construct_state_from_table(df, verbose=True)


pd.options.display.max_columns = None
df
# Out:
# Submitted pretest-1 EnvironmentState(NetworkState(e:7+0,c:23|n:7,e:12;s:1)@1/inf,a:H;p:0,t:0,s:0,h:0)
# Submitted pretest-1 EnvironmentState(NetworkState(e:7+0,c:23|n:7,e:12;s:1)@1/inf,a:H;p:0,t:0,s:1,h:0)
# Submitted pretest-2 EnvironmentState(NetworkState(e:7+0,c:38|n:7,e:12;s:1)@1/inf,a:H;p:0,t:0,s:0,h:0)
# Submitted pretest-2 EnvironmentState(NetworkState(e:7+0,c:38|n:7,e:12;s:1)@1/inf,a:H;p:0,t:0,s:1,h:0)
# Submitted pretest-3 EnvironmentState(NetworkState(e:6+0,c:22|n:7,e:12;s:1)@1/inf,a:H;p:0,t:0,s:0,h:0)
# Submitted pretest-3 EnvironmentState(NetworkState(e:6+0,c:22|n:7,e:12;s:1)@1/inf,a:H;p:0,t:0,s:1,h:0)
# Submitted pretest-4 EnvironmentState(NetworkState(e:6+0,c:45|n:7,e:12;s:1)@1/inf,a:H;p:0,t:0,s:0,h:0)
# Submitted pretest-4 EnvironmentState(NetworkState(e:6+0,c:45|n:7,e:12;s:1)@1/inf,a:H;p:0,t:0,s:1,h:0)
# Submitted pretest-5 EnvironmentState(NetworkState(e:6+0,c:15|n:7,e:12;s:1)@1/inf,a:H;p:0,t:0,s:0,h:0)
# Submitted pretest-5 EnvironmentState(NetworkState(e:6+0,c:15|n:7,e:12;s:1)@1/inf,a:H;p:0,t:0,s:1,h:0)
# Submitted collab-activity-1 EnvironmentState(NetworkState(e:14+0,c:38|n:10,e:20;s:1)@1/inf,a:R;p:0,t:0,s:0,h:0)
# Submitted collab-activity-1 EnvironmentState(NetworkState(e:11+0,c:29|n:10,e:20;s:1)@1/inf,a:H;p:0,t:0,s:0,h:0)
# Submitted collab-activity-1 EnvironmentState(NetworkState(e:11+0,c:29|n:10,e:20;s:1)@1/inf,a:R;p:0,t:0,s:0,h:0)
# Submitted collab-activity-1 EnvironmentState(NetworkState(e:12+1,c:32|n:10,e:20;s:1)@1/inf,a:H;p:0,t:0,s:0,h:0)
# Submitted collab-activity-2 EnvironmentState(NetworkState(e:10+0,c:42|n:10,e:20;s:0)@1/inf,a:R;p:0,t:0,s:0,h:0)
# Submitted collab-activity-2 EnvironmentState(NetworkState(e:11+0,c:47|n:10,e:20;s:1)@1/inf,a:H;p:0,t:0,s:0,h:0)
# Submitted collab-activity-2 EnvironmentState(NetworkState(e:9+0,c:35|n:10,e:20;s:1)@1/inf,a:H;p:0,t:0,s:0,h:0)
# Submitted posttest-1 EnvironmentState(NetworkState(e:6+0,c:15|n:7,e:12;s:1)@1/inf,a:H;p:0,t:0,s:0,h:0)
# Submitted posttest-1 EnvironmentState(NetworkState(e:6+0,c:15|n:7,e:12;s:1)@1/inf,a:H;p:0,t:0,s:1,h:0)
# Submitted posttest-2 EnvironmentState(NetworkState(e:6+0,c:30|n:7,e:12;s:1)@1/inf,a:H;p:0,t:0,s:0,h:0)
# Submitted posttest-2 EnvironmentState(NetworkState(e:6+0,c:30|n:7,e:12;s:1)@1/inf,a:H;p:0,t:0,s:1,h:0)
# Submitted posttest-3 EnvironmentState(NetworkState(e:6+0,c:21|n:7,e:12;s:1)@1/inf,a:H;p:0,t:0,s:0,h:0)
# Submitted posttest-3 EnvironmentState(NetworkState(e:6+0,c:21|n:7,e:12;s:1)@1/inf,a:H;p:0,t:0,s:1,h:0)
# Submitted posttest-4 EnvironmentState(NetworkState(e:6+0,c:45|n:7,e:12;s:1)@1/inf,a:H;p:0,t:0,s:0,h:0)
# Submitted posttest-4 EnvironmentState(NetworkState(e:6+0,c:45|n:7,e:12;s:1)@1/inf,a:H;p:0,t:0,s:1,h:0)
# Submitted posttest-5 EnvironmentState(NetworkState(e:6+0,c:16|n:7,e:12;s:1)@1/inf,a:H;p:0,t:0,s:0,h:0)
# Submitted posttest-5 EnvironmentState(NetworkState(e:6+0,c:16|n:7,e:12;s:1)@1/inf,a:H;p:0,t:0,s:1,h:0)
#             Time  header.seq    header.frame_id  \
# 0       0.000000           1   indiv-illustrate
# 1      36.886868           2   indiv-illustrate
# 2      54.157379           3   indiv-illustrate
# 3      56.384898           4   indiv-illustrate
# 4      96.414340           5          pretest-1
# 5     101.380167           6          pretest-1
# 6     107.648563           7          pretest-1
# 7     110.681328           8          pretest-1
# 8     119.594035           9          pretest-1
# 9     122.760478          10          pretest-1
# 10    131.729808          11          pretest-1
# 11    158.334580          12          pretest-1
# 12    161.277439          13          pretest-1
# 13    184.984782          14          pretest-2
# 14    191.952851          15          pretest-2
# 15    198.873079          16          pretest-2
# 16    204.539921          17          pretest-2
# 17    211.266092          18          pretest-2
# 18    213.319768          19          pretest-2
# 19    246.020485          20          pretest-2
# 20    248.563519          21          pretest-2
# 21    251.009743          22          pretest-2
# 22    273.714839          23          pretest-3
# 23    282.349756          24          pretest-3
# 24    282.386230          25          pretest-3
# 25    288.424070          26          pretest-3
# 26    293.715039          27          pretest-3
# 27    300.277377          28          pretest-3
# 28    304.044847          29          pretest-3
# 29    316.473500          30          pretest-3
# 30    319.224974          31          pretest-3
# 31    341.898535          32          pretest-4
# 32    346.824629          33          pretest-4
# 33    351.064605          34          pretest-4
# 34    360.684431          35          pretest-4
# 35    369.124192          36          pretest-4
# 36    376.566723          37          pretest-4
# 37    384.149373          38          pretest-4
# 38    386.282414          39          pretest-4
# 39    404.652614          40          pretest-5
# 40    409.868834          41          pretest-5
# 41    416.048428          42          pretest-5
# 42    420.087570          43          pretest-5
# 43    423.797529          44          pretest-5
# 44    429.915047          45          pretest-5
# 45    433.335552          46          pretest-5
# 46    435.368411          47          pretest-5
# 47    491.860260          48    collab-activity
# 48    502.980310          49    collab-activity
# 49    528.439899          50    collab-activity
# 50    537.716315          51    collab-activity
# 51    547.134391          52    collab-activity
# 52    552.858543          53    collab-activity
# 53    569.412335          54    collab-activity
# 54    578.270508          55    collab-activity
# 55    586.675547          56    collab-activity
# 56    593.798582          57    collab-activity
# 57    615.240996          58    collab-activity
# 58    620.568139          59    collab-activity
# 59    629.467384          60    collab-activity
# 60    638.896698          61    collab-activity
# 61    660.352259          62    collab-activity
# 62    669.208035          63    collab-activity
# 63    678.016373          64    collab-activity
# 64    681.704712          65    collab-activity
# 65    702.448704          66    collab-activity
# 66    715.292018          67    collab-activity
# 67    726.556824          68    collab-activity
# 68    743.720036          69    collab-activity
# 69    750.727077          70    collab-activity
# 70    760.138784          71    collab-activity
# 71    769.556840          72    collab-activity
# 72    788.101511          73    collab-activity
# 73    793.299503          74    collab-activity
# 74    801.637868          75    collab-activity
# 75    825.171204          76    collab-activity
# 76    833.868685          77    collab-activity
# 77    843.319270          78    collab-activity
# 78    849.756985          79    collab-activity
# 79    864.934668          80    collab-activity
# 80    871.968394          81    collab-activity
# 81    875.999134          82    collab-activity
# 82    884.849099          83    collab-activity
# 83    889.570805          84    collab-activity
# 84    894.866971          85    collab-activity
# 85    911.124619          86    collab-activity
# 86    916.294581          87    collab-activity
# 87    924.707977          88    collab-activity
# 88    930.090029          89    collab-activity
# 89    941.106134          90    collab-activity
# 90    949.379069          91    collab-activity
# 91    957.971216          92    collab-activity
# 92    965.496557          93    collab-activity
# 93    974.132659          94    collab-activity
# 94    981.193571          95    collab-activity
# 95    989.771402          96    collab-activity
# 96    996.356452          97    collab-activity
# 97   1005.967297          98    collab-activity
# 98   1014.962190          99    collab-activity
# 99   1023.299752         100    collab-activity
# 100  1033.359825         101    collab-activity
# 101  1049.695770         102    collab-activity
# 102  1056.677833         103    collab-activity
# 103  1065.283351         104    collab-activity
# 104  1075.486629         105    collab-activity
# 105  1095.491573         106    collab-activity
# 106  1114.107948         107    collab-activity
# 107  1122.728894         108    collab-activity
# 108  1132.461959         109    collab-activity
# 109  1136.674314         110    collab-activity
# 110  1146.910012         111    collab-activity
# 111  1156.010691         112    collab-activity
# 112  1164.623054         113    collab-activity
# 113  1168.529660         114    collab-activity
# 114  1178.571852         115    collab-activity
# 115  1187.873713         116    collab-activity
# 116  1197.431067         117    collab-activity
# 117  1208.510233         118    collab-activity
# 118  1218.203815         119    collab-activity
# 119  1227.286219         120    collab-activity
# 120  1236.731864         121    collab-activity
# 121  1239.829063         122    collab-activity
# 122  1248.558905         123    collab-activity
# 123  1257.586432         124    collab-activity
# 124  1266.192750         125    collab-activity
# 125  1273.986126         126    collab-activity
# 126  1284.424206         127    collab-activity
# 127  1291.990465         128    collab-activity
# 128  1296.024128         129    collab-activity
# 129  1304.687499         130    collab-activity
# 130  1310.261756         131    collab-activity
# 131  1314.722890         132    collab-activity
# 132  1320.346901         133    collab-activity
# 133  1331.733933         134    collab-activity
# 134  1341.349345         135    collab-activity
# 135  1345.082897         136    collab-activity
# 136  1360.568494         137    collab-activity
# 137  1367.976694         138    collab-activity
# 138  1376.989281         139    collab-activity
# 139  1380.528830         140    collab-activity
# 140  1386.224835         141    collab-activity
# 141  1395.433849         142    collab-activity
# 142  1403.824197         143    collab-activity
# 143  1408.292874         144    collab-activity
# 144  1425.894182         145    collab-activity
# 145  1434.936124         146    collab-activity
# 146  1444.569506         147    collab-activity
# 147  1452.345332         148    collab-activity
# 148  1460.438467         149    collab-activity
# 149  1468.766593         150    collab-activity
# 150  1478.626340         151    collab-activity
# 151  1479.649918         152    collab-activity
# 152  1489.126079         153    collab-activity
# 153  1499.100742         154    collab-activity
# 154  1508.712945         155    collab-activity
# 155  1513.415085         156    collab-activity
# 156  1575.674792         157  collab-activity-2
# 157  1584.973161         158  collab-activity-2
# 158  1599.531856         159  collab-activity-2
# 159  1608.621789         160  collab-activity-2
# 160  1618.046486         161  collab-activity-2
# 161  1627.861433         162  collab-activity-2
# 162  1639.634152         163  collab-activity-2
# 163  1651.239617         164  collab-activity-2
# 164  1656.538728         165  collab-activity-2
# 165  1671.030918         166  collab-activity-2
# 166  1682.971333         167  collab-activity-2
# 167  1691.092191         168  collab-activity-2
# 168  1705.890119         169  collab-activity-2
# 169  1713.090787         170  collab-activity-2
# 170  1721.501565         171  collab-activity-2
# 171  1730.691715         172  collab-activity-2
# 172  1750.459237         173  collab-activity-2
# 173  1759.792659         174  collab-activity-2
# 174  1769.427928         175  collab-activity-2
# 175  1773.898694         176  collab-activity-2
# 176  1782.499610         177  collab-activity-2
# 177  1789.955543         178  collab-activity-2
# 178  1798.580630         179  collab-activity-2
# 179  1803.393123         180  collab-activity-2
# 180  1810.460715         181  collab-activity-2
# 181  1901.745885         182  collab-activity-2
# 182  1907.733809         183  collab-activity-2
# 183  1927.351310         184  collab-activity-2
# 184  1936.736525         185  collab-activity-2
# 185  1940.771786         186  collab-activity-2
# 186  1949.614697         187  collab-activity-2
# 187  1955.469889         188  collab-activity-2
# 188  1966.853926         189  collab-activity-2
# 189  1974.869991         190  collab-activity-2
# 190  1988.358911         191  collab-activity-2
# 191  1991.091588         192  collab-activity-2
# 192  2001.373122         193  collab-activity-2
# 193  2013.752305         194  collab-activity-2
# 194  2016.463744         195  collab-activity-2
# 195  2025.621875         196  collab-activity-2
# 196  2034.418459         197  collab-activity-2
# 197  2044.185577         198  collab-activity-2
# 198  2048.402649         199  collab-activity-2
# 199  2060.582625         200  collab-activity-2
# 200  2072.117507         201  collab-activity-2
# 201  2075.181917         202  collab-activity-2
# 202  2086.456239         203  collab-activity-2
# 203  2091.576643         204  collab-activity-2
# 204  2105.435451         205  collab-activity-2
# 205  2120.750283         206  collab-activity-2
# 206  2128.047813         207  collab-activity-2
# 207  2136.434192         208  collab-activity-2
# 208  2143.562754         209  collab-activity-2
# 209  2153.412908         210  collab-activity-2
# 210  2162.458371         211  collab-activity-2
# 211  2171.227995         212  collab-activity-2
# 212  2178.211396         213  collab-activity-2
# 213  2187.168142         214  collab-activity-2
# 214  2199.351946         215  collab-activity-2
# 215  2203.846219         216  collab-activity-2
# 216  2213.643218         217  collab-activity-2
# 217  2219.164158         218  collab-activity-2
# 218  2228.381780         219  collab-activity-2
# 219  2229.757910         220  collab-activity-2
# 220  2237.362366         221  collab-activity-2
# 221  2263.581297         222  collab-activity-2
# 222  2270.766274         223  collab-activity-2
# 223  2279.995313         224  collab-activity-2
# 224  2285.622099         225  collab-activity-2
# 225  2294.258680         226  collab-activity-2
# 226  2303.742508         227  collab-activity-2
# 227  2313.157291         228  collab-activity-2
# 228  2318.912819         229  collab-activity-2
# 229  2329.389775         230  collab-activity-2
# 230  2337.739967         231  collab-activity-2
# 231  2346.129164         232  collab-activity-2
# 232  2351.045836         233  collab-activity-2
# 233  2359.578891         234  collab-activity-2
# 234  2368.311353         235  collab-activity-2
# 235  2377.905485         236  collab-activity-2
# 236  2382.508190         237  collab-activity-2
# 237  2394.713616         238  collab-activity-2
# 238  2403.899063         239  collab-activity-2
# 239  2412.090560         240  collab-activity-2
# 240  2417.082347         241  collab-activity-2
# 241  2426.823532         242  collab-activity-2
# 242  2436.244410         243  collab-activity-2
# 243  2445.458002         244  collab-activity-2
# 244  2451.472330         245  collab-activity-2
# 245  2461.466840         246  collab-activity-2
# 246  2499.226848         247         posttest-1
# 247  2502.156506         248         posttest-1
# 248  2505.392921         249         posttest-1
# 249  2509.289492         250         posttest-1
# 250  2512.933897         251         posttest-1
# 251  2517.725142         252         posttest-1
# 252  2527.368331         253         posttest-1
# 253  2528.898047         254         posttest-1
# 254  2539.630768         255         posttest-2
# 255  2542.832341         256         posttest-2
# 256  2545.064099         257         posttest-2
# 257  2549.876873         258         posttest-2
# 258  2551.934647         259         posttest-2
# 259  2560.546597         260         posttest-2
# 260  2562.039869         261         posttest-2
# 261  2563.587338         262         posttest-2
# 262  2574.468635         263         posttest-3
# 263  2577.363310         264         posttest-3
# 264  2579.436784         265         posttest-3
# 265  2581.798951         266         posttest-3
# 266  2584.596589         267         posttest-3
# 267  2590.407357         268         posttest-3
# 268  2600.212615         269         posttest-3
# 269  2601.809788         270         posttest-3
# 270  2619.770401         271         posttest-4
# 271  2622.091690         272         posttest-4
# 272  2634.968771         273         posttest-4
# 273  2638.599659         274         posttest-4
# 274  2640.743001         275         posttest-4
# 275  2642.641257         276         posttest-4
# 276  2651.660197         277         posttest-4
# 277  2654.021587         278         posttest-4
# 278  2669.379554         279         posttest-5
# 279  2672.516308         280         posttest-5
# 280  2675.951441         281         posttest-5
# 281  2678.788161         282         posttest-5
# 282  2687.300865         283         posttest-5
# 283  2689.521977         284         posttest-5
# 284  2691.576789         285         posttest-5
# 285  2693.588036         286         posttest-5
#
#                                            state.edges  state.suggested.u  \
# 0                                                   []                 -1
# 1                                         [u: 1\nv: 9]                 -1
# 2                                                   []                 -1
# 3                                         [u: 1\nv: 9]                 -1
# 4                                                   []                 -1
# 5                                         [u: 7\nv: 0]                 -1
# 6                             [u: 7\nv: 0, u: 0\nv: 3]                 -1
# 7                 [u: 7\nv: 0, u: 3\nv: 5, u: 0\nv: 3]                 -1
# 8     [u: 7\nv: 5, u: 7\nv: 0, u: 3\nv: 5, u: 0\nv: 3]                 -1
# 9    [u: 0\nv: 3, u: 7\nv: 5, u: 7\nv: 0, u: 5\nv: ...                 -1
# 10   [u: 7\nv: 5, u: 5\nv: 4, u: 0\nv: 3, u: 4\nv: ...                 -1
# 11   [u: 5\nv: 6, u: 7\nv: 5, u: 5\nv: 4, u: 0\nv: ...                 -1
# 12   [u: 5\nv: 4, u: 0\nv: 3, u: 7\nv: 0, u: 5\nv: ...                 -1
# 13                                                  []                 -1
# 14                                        [u: 4\nv: 6]                 -1
# 15                            [u: 6\nv: 7, u: 4\nv: 6]                 -1
# 16                [u: 6\nv: 7, u: 4\nv: 5, u: 4\nv: 6]                 -1
# 17    [u: 6\nv: 7, u: 4\nv: 5, u: 4\nv: 6, u: 4\nv: 1]                 -1
# 18   [u: 6\nv: 7, u: 4\nv: 5, u: 5\nv: 3, u: 4\nv: ...                 -1
# 19   [u: 6\nv: 7, u: 4\nv: 5, u: 5\nv: 3, u: 4\nv: ...                 -1
# 20   [u: 6\nv: 7, u: 4\nv: 5, u: 5\nv: 3, u: 4\nv: ...                 -1
# 21   [u: 4\nv: 6, u: 5\nv: 7, u: 3\nv: 0, u: 6\nv: ...                 -1
# 22                                                  []                 -1
# 23                                        [u: 0\nv: 3]                 -1
# 24                            [u: 3\nv: 1, u: 0\nv: 3]                 -1
# 25                            [u: 3\nv: 1, u: 0\nv: 3]                 -1
# 26                [u: 3\nv: 1, u: 0\nv: 3, u: 1\nv: 4]                 -1
# 27    [u: 3\nv: 1, u: 4\nv: 5, u: 0\nv: 3, u: 1\nv: 4]                 -1
# 28   [u: 4\nv: 5, u: 7\nv: 6, u: 3\nv: 1, u: 0\nv: ...                 -1
# 29   [u: 4\nv: 5, u: 7\nv: 6, u: 5\nv: 7, u: 3\nv: ...                 -1
# 30   [u: 3\nv: 1, u: 0\nv: 3, u: 5\nv: 7, u: 1\nv: ...                 -1
# 31                                                  []                 -1
# 32                                        [u: 6\nv: 4]                 -1
# 33                            [u: 6\nv: 7, u: 6\nv: 4]                 -1
# 34                [u: 6\nv: 7, u: 4\nv: 1, u: 6\nv: 4]                 -1
# 35    [u: 6\nv: 7, u: 4\nv: 5, u: 4\nv: 1, u: 6\nv: 4]                 -1
# 36   [u: 6\nv: 7, u: 4\nv: 5, u: 3\nv: 1, u: 4\nv: ...                 -1
# 37   [u: 6\nv: 7, u: 4\nv: 5, u: 3\nv: 1, u: 4\nv: ...                 -1
# 38   [u: 3\nv: 1, u: 6\nv: 4, u: 3\nv: 0, u: 6\nv: ...                 -1
# 39                                                  []                 -1
# 40                                        [u: 0\nv: 3]                 -1
# 41                            [u: 0\nv: 3, u: 1\nv: 3]                 -1
# 42                [u: 0\nv: 3, u: 1\nv: 3, u: 1\nv: 4]                 -1
# 43    [u: 5\nv: 4, u: 0\nv: 3, u: 1\nv: 3, u: 1\nv: 4]                 -1
# 44   [u: 4\nv: 6, u: 5\nv: 4, u: 0\nv: 3, u: 1\nv: ...                 -1
# 45   [u: 6\nv: 7, u: 0\nv: 3, u: 5\nv: 4, u: 4\nv: ...                 -1
# 46   [u: 5\nv: 4, u: 4\nv: 6, u: 0\nv: 3, u: 1\nv: ...                 -1
# 47                                                  []                 -1
# 48                                                  []                  0
# 49                                        [u: 0\nv: 3]                 -1
# 50                                        [u: 0\nv: 3]                  2
# 51                            [u: 0\nv: 3, u: 2\nv: 1]                 -1
# 52                            [u: 0\nv: 3, u: 2\nv: 1]                  2
# 53                [u: 2\nv: 3, u: 0\nv: 3, u: 2\nv: 1]                 -1
# 54                [u: 2\nv: 3, u: 0\nv: 3, u: 2\nv: 1]                  8
# 55    [u: 2\nv: 3, u: 8\nv: 9, u: 0\nv: 3, u: 2\nv: 1]                 -1
# 56    [u: 2\nv: 3, u: 8\nv: 9, u: 2\nv: 1, u: 0\nv: 3]                  8
# 57   [u: 2\nv: 3, u: 8\nv: 9, u: 2\nv: 1, u: 8\nv: ...                 -1
# 58   [u: 2\nv: 1, u: 0\nv: 3, u: 2\nv: 3, u: 8\nv: ...                  5
# 59   [u: 2\nv: 3, u: 8\nv: 9, u: 2\nv: 1, u: 8\nv: ...                 -1
# 60   [u: 2\nv: 1, u: 5\nv: 4, u: 0\nv: 3, u: 2\nv: ...                  5
# 61   [u: 2\nv: 3, u: 8\nv: 9, u: 2\nv: 1, u: 8\nv: ...                 -1
# 62   [u: 2\nv: 1, u: 5\nv: 4, u: 0\nv: 3, u: 5\nv: ...                  6
# 63   [u: 2\nv: 3, u: 8\nv: 9, u: 2\nv: 1, u: 8\nv: ...                 -1
# 64   [u: 2\nv: 1, u: 5\nv: 4, u: 0\nv: 3, u: 6\nv: ...                  6
# 65   [u: 2\nv: 1, u: 5\nv: 4, u: 0\nv: 3, u: 6\nv: ...                 -1
# 66   [u: 2\nv: 1, u: 5\nv: 4, u: 0\nv: 3, u: 6\nv: ...                  1
# 67   [u: 2\nv: 1, u: 5\nv: 4, u: 0\nv: 3, u: 6\nv: ...                  1
# 68   [u: 2\nv: 1, u: 5\nv: 4, u: 0\nv: 3, u: 6\nv: ...                 -1
# 69   [u: 2\nv: 1, u: 5\nv: 4, u: 0\nv: 3, u: 6\nv: ...                  1
# 70   [u: 2\nv: 1, u: 5\nv: 4, u: 0\nv: 3, u: 6\nv: ...                 -1
# 71   [u: 2\nv: 1, u: 5\nv: 4, u: 0\nv: 3, u: 6\nv: ...                  1
# 72   [u: 2\nv: 1, u: 5\nv: 4, u: 0\nv: 3, u: 6\nv: ...                 -1
# 73   [u: 2\nv: 1, u: 5\nv: 4, u: 0\nv: 3, u: 6\nv: ...                  4
# 74   [u: 2\nv: 1, u: 5\nv: 4, u: 0\nv: 3, u: 6\nv: ...                  4
# 75   [u: 2\nv: 1, u: 4\nv: 1, u: 5\nv: 4, u: 0\nv: ...                 -1
# 76   [u: 1\nv: 3, u: 2\nv: 1, u: 5\nv: 4, u: 0\nv: ...                  7
# 77   [u: 2\nv: 1, u: 4\nv: 1, u: 5\nv: 4, u: 0\nv: ...                 -1
# 78   [u: 1\nv: 3, u: 2\nv: 1, u: 5\nv: 4, u: 0\nv: ...                  7
# 79   [u: 2\nv: 1, u: 4\nv: 1, u: 5\nv: 4, u: 0\nv: ...                 -1
# 80   [u: 1\nv: 3, u: 2\nv: 1, u: 5\nv: 4, u: 0\nv: ...                  4
# 81   [u: 2\nv: 1, u: 4\nv: 1, u: 4\nv: 9, u: 5\nv: ...                 -1
# 82                                                  []                 -1
# 83                                                  []                 -1
# 84                                                  []                  4
# 85                                        [u: 4\nv: 5]                 -1
# 86                                        [u: 4\nv: 5]                  6
# 87                            [u: 4\nv: 5, u: 6\nv: 4]                 -1
# 88                            [u: 4\nv: 5, u: 6\nv: 4]                  6
# 89                [u: 6\nv: 7, u: 4\nv: 5, u: 6\nv: 4]                 -1
# 90                [u: 6\nv: 7, u: 4\nv: 5, u: 6\nv: 4]                  4
# 91    [u: 4\nv: 9, u: 6\nv: 7, u: 4\nv: 5, u: 6\nv: 4]                 -1
# 92    [u: 4\nv: 9, u: 6\nv: 7, u: 4\nv: 5, u: 6\nv: 4]                  4
# 93   [u: 6\nv: 7, u: 4\nv: 5, u: 4\nv: 9, u: 4\nv: ...                 -1
# 94   [u: 4\nv: 9, u: 6\nv: 4, u: 6\nv: 7, u: 4\nv: ...                  2
# 95   [u: 6\nv: 7, u: 4\nv: 5, u: 2\nv: 1, u: 4\nv: ...                 -1
# 96   [u: 2\nv: 1, u: 4\nv: 9, u: 6\nv: 4, u: 6\nv: ...                  2
# 97   [u: 2\nv: 3, u: 6\nv: 7, u: 4\nv: 5, u: 2\nv: ...                 -1
# 98   [u: 2\nv: 1, u: 4\nv: 9, u: 6\nv: 4, u: 2\nv: ...                  8
# 99   [u: 2\nv: 3, u: 6\nv: 7, u: 4\nv: 5, u: 8\nv: ...                 -1
# 100  [u: 2\nv: 1, u: 4\nv: 9, u: 6\nv: 4, u: 2\nv: ...                  8
# 101  [u: 2\nv: 1, u: 4\nv: 9, u: 6\nv: 4, u: 2\nv: ...                 -1
# 102  [u: 2\nv: 1, u: 4\nv: 9, u: 6\nv: 4, u: 2\nv: ...                  0
# 103  [u: 2\nv: 1, u: 4\nv: 9, u: 0\nv: 3, u: 6\nv: ...                 -1
# 104  [u: 2\nv: 1, u: 4\nv: 9, u: 0\nv: 3, u: 6\nv: ...                  0
# 105  [u: 0\nv: 7, u: 2\nv: 1, u: 4\nv: 9, u: 0\nv: ...                 -1
# 106                                                 []                 -1
# 107                                                 []                  2
# 108                                       [u: 2\nv: 1]                 -1
# 109                                       [u: 2\nv: 1]                  2
# 110                           [u: 2\nv: 3, u: 2\nv: 1]                 -1
# 111                           [u: 2\nv: 3, u: 2\nv: 1]                  6
# 112               [u: 2\nv: 3, u: 6\nv: 4, u: 2\nv: 1]                 -1
# 113               [u: 2\nv: 3, u: 2\nv: 1, u: 6\nv: 4]                  6
# 114   [u: 2\nv: 3, u: 6\nv: 7, u: 6\nv: 4, u: 2\nv: 1]                 -1
# 115   [u: 2\nv: 3, u: 6\nv: 7, u: 2\nv: 1, u: 6\nv: 4]                  4
# 116  [u: 2\nv: 3, u: 6\nv: 7, u: 4\nv: 5, u: 2\nv: ...                 -1
# 117  [u: 2\nv: 1, u: 6\nv: 4, u: 2\nv: 3, u: 6\nv: ...                  4
# 118  [u: 2\nv: 3, u: 6\nv: 7, u: 4\nv: 5, u: 2\nv: ...                 -1
# 119  [u: 2\nv: 1, u: 6\nv: 4, u: 2\nv: 3, u: 6\nv: ...                  8
# 120  [u: 2\nv: 3, u: 6\nv: 7, u: 4\nv: 5, u: 8\nv: ...                 -1
# 121  [u: 2\nv: 1, u: 6\nv: 4, u: 2\nv: 3, u: 6\nv: ...                  8
# 122  [u: 2\nv: 3, u: 6\nv: 7, u: 4\nv: 5, u: 8\nv: ...                 -1
# 123  [u: 2\nv: 1, u: 6\nv: 4, u: 2\nv: 3, u: 6\nv: ...                  0
# 124  [u: 2\nv: 1, u: 0\nv: 3, u: 6\nv: 4, u: 2\nv: ...                 -1
# 125  [u: 2\nv: 1, u: 0\nv: 3, u: 6\nv: 4, u: 2\nv: ...                  0
# 126  [u: 0\nv: 7, u: 2\nv: 1, u: 0\nv: 3, u: 6\nv: ...                 -1
# 127  [u: 0\nv: 7, u: 2\nv: 1, u: 0\nv: 3, u: 6\nv: ...                  4
# 128  [u: 0\nv: 7, u: 2\nv: 1, u: 4\nv: 9, u: 0\nv: ...                 -1
# 129                                                 []                 -1
# 130                                                 []                 -1
# 131                                                 []                  4
# 132                                       [u: 4\nv: 5]                 -1
# 133                                       [u: 4\nv: 5]                  6
# 134                           [u: 4\nv: 5, u: 6\nv: 4]                 -1
# 135                           [u: 4\nv: 5, u: 6\nv: 4]                  6
# 136               [u: 6\nv: 7, u: 4\nv: 5, u: 6\nv: 4]                 -1
# 137               [u: 6\nv: 7, u: 4\nv: 5, u: 6\nv: 4]                  1
# 138   [u: 6\nv: 7, u: 4\nv: 5, u: 1\nv: 2, u: 6\nv: 4]                 -1
# 139   [u: 6\nv: 7, u: 4\nv: 5, u: 1\nv: 2, u: 6\nv: 4]                  1
# 140  [u: 6\nv: 7, u: 4\nv: 5, u: 1\nv: 2, u: 1\nv: ...                 -1
# 141  [u: 1\nv: 2, u: 6\nv: 4, u: 6\nv: 7, u: 4\nv: ...                  8
# 142  [u: 6\nv: 7, u: 4\nv: 5, u: 1\nv: 2, u: 8\nv: ...                 -1
# 143  [u: 1\nv: 2, u: 6\nv: 4, u: 6\nv: 7, u: 4\nv: ...                  8
# 144  [u: 6\nv: 7, u: 4\nv: 5, u: 1\nv: 2, u: 8\nv: ...                 -1
# 145  [u: 1\nv: 2, u: 6\nv: 4, u: 6\nv: 7, u: 4\nv: ...                  0
# 146  [u: 6\nv: 7, u: 4\nv: 5, u: 1\nv: 2, u: 8\nv: ...                 -1
# 147  [u: 1\nv: 2, u: 0\nv: 3, u: 6\nv: 4, u: 6\nv: ...                  0
# 148  [u: 0\nv: 7, u: 1\nv: 2, u: 0\nv: 3, u: 6\nv: ...                 -1
# 149  [u: 0\nv: 7, u: 1\nv: 2, u: 0\nv: 3, u: 6\nv: ...                  4
# 150  [u: 0\nv: 7, u: 1\nv: 2, u: 4\nv: 9, u: 0\nv: ...                 -1
# 151  [u: 0\nv: 7, u: 1\nv: 2, u: 4\nv: 9, u: 0\nv: ...                  4
# 152  [u: 0\nv: 7, u: 1\nv: 2, u: 4\nv: 1, u: 4\nv: ...                 -1
# 153  [u: 0\nv: 7, u: 1\nv: 3, u: 1\nv: 2, u: 4\nv: ...                  1
# 154  [u: 0\nv: 7, u: 1\nv: 2, u: 4\nv: 1, u: 4\nv: ...                 -1
# 155  [u: 0\nv: 7, u: 1\nv: 3, u: 1\nv: 2, u: 4\nv: ...                  1
# 156                                                 []                 -1
# 157                                                 []                  0
# 158                                                 []                 -1
# 159                                                 []                  9
# 160                                       [u: 9\nv: 8]                 -1
# 161                                       [u: 9\nv: 8]                  9
# 162                                       [u: 9\nv: 8]                 -1
# 163                                       [u: 9\nv: 8]                  4
# 164                                       [u: 9\nv: 8]                  4
# 165                           [u: 4\nv: 5, u: 9\nv: 8]                 -1
# 166                           [u: 4\nv: 5, u: 9\nv: 8]                  6
# 167                           [u: 4\nv: 5, u: 9\nv: 8]                  6
# 168               [u: 4\nv: 5, u: 6\nv: 4, u: 9\nv: 8]                 -1
# 169               [u: 9\nv: 8, u: 4\nv: 5, u: 6\nv: 4]                  6
# 170   [u: 6\nv: 7, u: 4\nv: 5, u: 6\nv: 4, u: 9\nv: 8]                 -1
# 171   [u: 9\nv: 8, u: 6\nv: 7, u: 4\nv: 5, u: 6\nv: 4]                  6
# 172  [u: 6\nv: 7, u: 4\nv: 5, u: 9\nv: 8, u: 6\nv: ...                 -1
# 173  [u: 6\nv: 5, u: 6\nv: 4, u: 6\nv: 7, u: 4\nv: ...                  1
# 174  [u: 6\nv: 7, u: 4\nv: 5, u: 1\nv: 2, u: 9\nv: ...                 -1
# 175  [u: 1\nv: 2, u: 6\nv: 5, u: 6\nv: 4, u: 6\nv: ...                  1
# 176  [u: 6\nv: 7, u: 4\nv: 5, u: 1\nv: 2, u: 9\nv: ...                 -1
# 177  [u: 1\nv: 2, u: 6\nv: 5, u: 6\nv: 4, u: 6\nv: ...                  3
# 178  [u: 6\nv: 7, u: 4\nv: 5, u: 1\nv: 2, u: 9\nv: ...                 -1
# 179  [u: 1\nv: 2, u: 6\nv: 5, u: 6\nv: 4, u: 3\nv: ...                  3
# 180  [u: 1\nv: 2, u: 6\nv: 5, u: 6\nv: 4, u: 3\nv: ...                 -1
# 181  [u: 1\nv: 2, u: 6\nv: 5, u: 6\nv: 4, u: 3\nv: ...                  8
# 182  [u: 1\nv: 2, u: 6\nv: 5, u: 6\nv: 4, u: 3\nv: ...                  0
# 183  [u: 1\nv: 2, u: 6\nv: 5, u: 0\nv: 3, u: 6\nv: ...                 -1
# 184  [u: 1\nv: 2, u: 6\nv: 5, u: 0\nv: 3, u: 6\nv: ...                  8
# 185  [u: 1\nv: 2, u: 6\nv: 5, u: 0\nv: 3, u: 6\nv: ...                 -1
# 186                                                 []                 -1
# 187                                                 []                 -1
# 188                                                 []                  8
# 189                                       [u: 8\nv: 9]                 -1
# 190                                       [u: 8\nv: 9]                  9
# 191                                       [u: 8\nv: 9]                  9
# 192                           [u: 9\nv: 1, u: 8\nv: 9]                 -1
# 193                           [u: 8\nv: 9, u: 9\nv: 1]                  1
# 194                           [u: 9\nv: 1, u: 8\nv: 9]                  1
# 195               [u: 8\nv: 9, u: 1\nv: 2, u: 9\nv: 1]                 -1
# 196               [u: 9\nv: 1, u: 1\nv: 2, u: 8\nv: 9]                  9
# 197   [u: 8\nv: 9, u: 1\nv: 2, u: 9\nv: 1, u: 9\nv: 4]                 -1
# 198   [u: 9\nv: 1, u: 1\nv: 2, u: 8\nv: 9, u: 9\nv: 4]                  9
# 199   [u: 8\nv: 9, u: 1\nv: 2, u: 9\nv: 1, u: 9\nv: 4]                 -1
# 200   [u: 9\nv: 1, u: 1\nv: 2, u: 8\nv: 9, u: 9\nv: 4]                  4
# 201   [u: 8\nv: 9, u: 1\nv: 2, u: 9\nv: 1, u: 9\nv: 4]                  4
# 202  [u: 4\nv: 5, u: 1\nv: 2, u: 8\nv: 9, u: 9\nv: ...                 -1
# 203  [u: 1\nv: 2, u: 4\nv: 5, u: 8\nv: 9, u: 9\nv: ...                  6
# 204  [u: 1\nv: 2, u: 4\nv: 5, u: 8\nv: 9, u: 9\nv: ...                  6
# 205  [u: 4\nv: 5, u: 1\nv: 2, u: 8\nv: 9, u: 9\nv: ...                 -1
# 206  [u: 1\nv: 2, u: 6\nv: 4, u: 4\nv: 5, u: 8\nv: ...                  6
# 207  [u: 6\nv: 7, u: 4\nv: 5, u: 1\nv: 2, u: 8\nv: ...                 -1
# 208  [u: 1\nv: 2, u: 6\nv: 4, u: 6\nv: 7, u: 4\nv: ...                  6
# 209  [u: 1\nv: 2, u: 6\nv: 4, u: 6\nv: 7, u: 4\nv: ...                 -1
# 210  [u: 1\nv: 2, u: 6\nv: 4, u: 6\nv: 7, u: 4\nv: ...                  5
# 211  [u: 6\nv: 7, u: 4\nv: 5, u: 1\nv: 2, u: 8\nv: ...                 -1
# 212  [u: 1\nv: 2, u: 6\nv: 4, u: 5\nv: 7, u: 6\nv: ...                  5
# 213  [u: 1\nv: 2, u: 6\nv: 4, u: 5\nv: 7, u: 6\nv: ...                 -1
# 214  [u: 1\nv: 2, u: 6\nv: 4, u: 5\nv: 7, u: 6\nv: ...                  3
# 215  [u: 1\nv: 2, u: 6\nv: 4, u: 5\nv: 7, u: 6\nv: ...                  3
# 216  [u: 1\nv: 2, u: 6\nv: 4, u: 5\nv: 7, u: 6\nv: ...                 -1
# 217  [u: 1\nv: 2, u: 6\nv: 4, u: 5\nv: 7, u: 6\nv: ...                  3
# 218  [u: 1\nv: 2, u: 6\nv: 4, u: 5\nv: 7, u: 3\nv: ...                 -1
# 219  [u: 1\nv: 2, u: 6\nv: 4, u: 5\nv: 7, u: 3\nv: ...                  3
# 220  [u: 1\nv: 2, u: 3\nv: 1, u: 6\nv: 4, u: 5\nv: ...                 -1
# 221                                                 []                 -1
# 222                                                 []                  1
# 223                                       [u: 1\nv: 2]                 -1
# 224                                       [u: 1\nv: 2]                  1
# 225                           [u: 1\nv: 2, u: 1\nv: 3]                 -1
# 226                           [u: 1\nv: 2, u: 1\nv: 3]                  9
# 227               [u: 1\nv: 2, u: 1\nv: 3, u: 9\nv: 8]                 -1
# 228               [u: 1\nv: 2, u: 1\nv: 3, u: 9\nv: 8]                  9
# 229   [u: 9\nv: 1, u: 1\nv: 2, u: 1\nv: 3, u: 9\nv: 8]                 -1
# 230   [u: 1\nv: 2, u: 9\nv: 1, u: 1\nv: 3, u: 9\nv: 8]                  4
# 231  [u: 1\nv: 2, u: 9\nv: 8, u: 4\nv: 9, u: 9\nv: ...                 -1
# 232  [u: 1\nv: 2, u: 4\nv: 9, u: 9\nv: 8, u: 9\nv: ...                  4
# 233  [u: 4\nv: 5, u: 1\nv: 2, u: 9\nv: 8, u: 4\nv: ...                 -1
# 234  [u: 1\nv: 2, u: 4\nv: 9, u: 4\nv: 5, u: 9\nv: ...                  3
# 235  [u: 4\nv: 5, u: 1\nv: 2, u: 9\nv: 8, u: 4\nv: ...                 -1
# 236  [u: 1\nv: 2, u: 4\nv: 9, u: 3\nv: 0, u: 4\nv: ...                  3
# 237  [u: 1\nv: 2, u: 4\nv: 9, u: 3\nv: 0, u: 4\nv: ...                 -1
# 238  [u: 1\nv: 2, u: 4\nv: 9, u: 3\nv: 0, u: 4\nv: ...                  4
# 239  [u: 4\nv: 6, u: 4\nv: 5, u: 1\nv: 2, u: 9\nv: ...                 -1
# 240  [u: 1\nv: 2, u: 4\nv: 9, u: 4\nv: 6, u: 3\nv: ...                  4
# 241  [u: 1\nv: 2, u: 4\nv: 9, u: 4\nv: 6, u: 3\nv: ...                 -1
# 242  [u: 1\nv: 2, u: 4\nv: 9, u: 4\nv: 6, u: 3\nv: ...                  6
# 243  [u: 1\nv: 2, u: 4\nv: 9, u: 4\nv: 6, u: 3\nv: ...                 -1
# 244  [u: 1\nv: 2, u: 4\nv: 9, u: 4\nv: 6, u: 3\nv: ...                  6
# 245  [u: 1\nv: 2, u: 4\nv: 9, u: 4\nv: 6, u: 3\nv: ...                 -1
# 246                                                 []                 -1
# 247                                       [u: 0\nv: 3]                 -1
# 248                           [u: 3\nv: 1, u: 0\nv: 3]                 -1
# 249               [u: 3\nv: 1, u: 0\nv: 3, u: 1\nv: 4]                 -1
# 250   [u: 3\nv: 1, u: 5\nv: 4, u: 0\nv: 3, u: 1\nv: 4]                 -1
# 251  [u: 3\nv: 1, u: 5\nv: 4, u: 0\nv: 3, u: 6\nv: ...                 -1
# 252  [u: 7\nv: 6, u: 3\nv: 1, u: 5\nv: 4, u: 0\nv: ...                 -1
# 253  [u: 3\nv: 1, u: 5\nv: 4, u: 0\nv: 3, u: 6\nv: ...                 -1
# 254                                                 []                 -1
# 255                                       [u: 6\nv: 7]                 -1
# 256                           [u: 6\nv: 7, u: 4\nv: 6]                 -1
# 257               [u: 6\nv: 7, u: 4\nv: 5, u: 4\nv: 6]                 -1
# 258   [u: 6\nv: 7, u: 4\nv: 5, u: 4\nv: 6, u: 3\nv: 0]                 -1
# 259  [u: 6\nv: 7, u: 4\nv: 5, u: 4\nv: 6, u: 1\nv: ...                 -1
# 260  [u: 6\nv: 7, u: 4\nv: 5, u: 4\nv: 1, u: 4\nv: ...                 -1
# 261  [u: 1\nv: 3, u: 4\nv: 6, u: 3\nv: 0, u: 6\nv: ...                 -1
# 262                                                 []                 -1
# 263                                       [u: 1\nv: 3]                 -1
# 264                           [u: 1\nv: 3, u: 3\nv: 0]                 -1
# 265               [u: 1\nv: 3, u: 1\nv: 4, u: 3\nv: 0]                 -1
# 266   [u: 4\nv: 5, u: 1\nv: 3, u: 1\nv: 4, u: 3\nv: 0]                 -1
# 267  [u: 4\nv: 5, u: 7\nv: 6, u: 1\nv: 3, u: 1\nv: ...                 -1
# 268  [u: 4\nv: 5, u: 7\nv: 6, u: 4\nv: 6, u: 1\nv: ...                 -1
# 269  [u: 4\nv: 6, u: 1\nv: 4, u: 3\nv: 0, u: 4\nv: ...                 -1
# 270                                                 []                 -1
# 271                                       [u: 4\nv: 6]                 -1
# 272                           [u: 6\nv: 7, u: 4\nv: 6]                 -1
# 273               [u: 6\nv: 7, u: 5\nv: 4, u: 4\nv: 6]                 -1
# 274   [u: 6\nv: 7, u: 5\nv: 4, u: 4\nv: 6, u: 4\nv: 1]                 -1
# 275  [u: 6\nv: 7, u: 1\nv: 3, u: 5\nv: 4, u: 4\nv: ...                 -1
# 276  [u: 6\nv: 7, u: 1\nv: 3, u: 5\nv: 4, u: 4\nv: ...                 -1
# 277  [u: 4\nv: 1, u: 5\nv: 4, u: 4\nv: 6, u: 3\nv: ...                 -1
# 278                                                 []                 -1
# 279                                       [u: 0\nv: 3]                 -1
# 280                           [u: 0\nv: 3, u: 6\nv: 4]                 -1
# 281               [u: 5\nv: 4, u: 0\nv: 3, u: 6\nv: 4]                 -1
# 282   [u: 5\nv: 4, u: 0\nv: 3, u: 6\nv: 4, u: 1\nv: 4]                 -1
# 283  [u: 7\nv: 0, u: 5\nv: 4, u: 0\nv: 3, u: 6\nv: ...                 -1
# 284  [u: 7\nv: 6, u: 0\nv: 3, u: 5\nv: 4, u: 7\nv: ...                 -1
# 285  [u: 5\nv: 4, u: 7\nv: 0, u: 0\nv: 3, u: 6\nv: ...                 -1
#
#      state.suggested.v  state.terminal  state.submit_suggested  \
# 0                   -1           False                   False
# 1                   -1           False                   False
# 2                   -1           False                   False
# 3                   -1           False                   False
# 4                   -1           False                   False
# 5                   -1           False                   False
# 6                   -1           False                   False
# 7                   -1           False                   False
# 8                   -1           False                   False
# 9                   -1           False                   False
# 10                  -1           False                   False
# 11                  -1           False                   False
# 12                  -1           False                    True
# 13                  -1           False                   False
# 14                  -1           False                   False
# 15                  -1           False                   False
# 16                  -1           False                   False
# 17                  -1           False                   False
# 18                  -1           False                   False
# 19                  -1           False                   False
# 20                  -1           False                   False
# 21                  -1           False                    True
# 22                  -1           False                   False
# 23                  -1           False                   False
# 24                  -1           False                   False
# 25                  -1           False                   False
# 26                  -1           False                   False
# 27                  -1           False                   False
# 28                  -1           False                   False
# 29                  -1           False                   False
# 30                  -1           False                    True
# 31                  -1           False                   False
# 32                  -1           False                   False
# 33                  -1           False                   False
# 34                  -1           False                   False
# 35                  -1           False                   False
# 36                  -1           False                   False
# 37                  -1           False                   False
# 38                  -1           False                    True
# 39                  -1           False                   False
# 40                  -1           False                   False
# 41                  -1           False                   False
# 42                  -1           False                   False
# 43                  -1           False                   False
# 44                  -1           False                   False
# 45                  -1           False                   False
# 46                  -1           False                    True
# 47                  -1           False                   False
# 48                   3           False                   False
# 49                  -1           False                   False
# 50                   1           False                   False
# 51                  -1           False                   False
# 52                   3           False                   False
# 53                  -1           False                   False
# 54                   9           False                   False
# 55                  -1           False                   False
# 56                   2           False                   False
# 57                  -1           False                   False
# 58                   4           False                   False
# 59                  -1           False                   False
# 60                   7           False                   False
# 61                  -1           False                   False
# 62                   4           False                   False
# 63                  -1           False                   False
# 64                   7           False                   False
# 65                  -1           False                   False
# 66                   4           False                   False
# 67                   3           False                   False
# 68                  -1           False                   False
# 69                   9           False                   False
# 70                  -1           False                   False
# 71                   4           False                   False
# 72                  -1           False                   False
# 73                   9           False                   False
# 74                   1           False                   False
# 75                  -1           False                   False
# 76                   0           False                   False
# 77                  -1           False                   False
# 78                   3           False                   False
# 79                  -1           False                   False
# 80                   9           False                   False
# 81                  -1           False                   False
# 82                  -1           False                   False
# 83                  -1           False                   False
# 84                   5           False                   False
# 85                  -1           False                   False
# 86                   4           False                   False
# 87                  -1           False                   False
# 88                   7           False                   False
# 89                  -1           False                   False
# 90                   9           False                   False
# 91                  -1           False                   False
# 92                   1           False                   False
# 93                  -1           False                   False
# 94                   1           False                   False
# 95                  -1           False                   False
# 96                   3           False                   False
# 97                  -1           False                   False
# 98                   9           False                   False
# 99                  -1           False                   False
# 100                  2           False                   False
# 101                 -1           False                   False
# 102                  3           False                   False
# 103                 -1           False                   False
# 104                  7           False                   False
# 105                 -1           False                   False
# 106                 -1           False                   False
# 107                  1           False                   False
# 108                 -1           False                   False
# 109                  3           False                   False
# 110                 -1           False                   False
# 111                  4           False                   False
# 112                 -1           False                   False
# 113                  7           False                   False
# 114                 -1           False                   False
# 115                  5           False                   False
# 116                 -1           False                   False
# 117                  1           False                   False
# 118                 -1           False                   False
# 119                  9           False                   False
# 120                 -1           False                   False
# 121                  2           False                   False
# 122                 -1           False                   False
# 123                  3           False                   False
# 124                 -1           False                   False
# 125                  7           False                   False
# ...
# 6    EnvironmentState(NetworkState(e:2+0,c:7|n:7,e:...
# 7    EnvironmentState(NetworkState(e:3+0,c:11|n:7,e...
# 8    EnvironmentState(NetworkState(e:4+0,c:14|n:7,e...
# 9    EnvironmentState(NetworkState(e:5+0,c:16|n:7,e...
# 10   EnvironmentState(NetworkState(e:6+0,c:19|n:7,e...
# 11   EnvironmentState(NetworkState(e:7+0,c:23|n:7,e...
# 12   EnvironmentState(NetworkState(e:7+0,c:23|n:7,e...
# 13   EnvironmentState(NetworkState(e:0+0,c:0|n:7,e:...
# 14   EnvironmentState(NetworkState(e:1+0,c:4|n:7,e:...
# 15   EnvironmentState(NetworkState(e:2+0,c:8|n:7,e:...
# 16   EnvironmentState(NetworkState(e:3+0,c:12|n:7,e...
# 17   EnvironmentState(NetworkState(e:4+0,c:18|n:7,e...
# 18   EnvironmentState(NetworkState(e:5+0,c:26|n:7,e...
# 19   EnvironmentState(NetworkState(e:6+0,c:32|n:7,e...
# 20   EnvironmentState(NetworkState(e:7+0,c:38|n:7,e...
# 21   EnvironmentState(NetworkState(e:7+0,c:38|n:7,e...
# 22   EnvironmentState(NetworkState(e:0+0,c:0|n:7,e:...
# 23   EnvironmentState(NetworkState(e:1+0,c:4|n:7,e:...
# 24   EnvironmentState(NetworkState(e:2+0,c:8|n:7,e:...
# 25   EnvironmentState(NetworkState(e:2+0,c:8|n:7,e:...
# 26   EnvironmentState(NetworkState(e:3+0,c:12|n:7,e...
# 27   EnvironmentState(NetworkState(e:4+0,c:15|n:7,e...
# 28   EnvironmentState(NetworkState(e:5+0,c:18|n:7,e...
# 29   EnvironmentState(NetworkState(e:6+0,c:22|n:7,e...
# 30   EnvironmentState(NetworkState(e:6+0,c:22|n:7,e...
# 31   EnvironmentState(NetworkState(e:0+0,c:0|n:7,e:...
# 32   EnvironmentState(NetworkState(e:1+0,c:7|n:7,e:...
# 33   EnvironmentState(NetworkState(e:2+0,c:14|n:7,e...
# 34   EnvironmentState(NetworkState(e:3+0,c:22|n:7,e...
# 35   EnvironmentState(NetworkState(e:4+0,c:29|n:7,e...
# 36   EnvironmentState(NetworkState(e:5+0,c:37|n:7,e...
# 37   EnvironmentState(NetworkState(e:6+0,c:45|n:7,e...
# 38   EnvironmentState(NetworkState(e:6+0,c:45|n:7,e...
# 39   EnvironmentState(NetworkState(e:0+0,c:0|n:7,e:...
# 40   EnvironmentState(NetworkState(e:1+0,c:3|n:7,e:...
# 41   EnvironmentState(NetworkState(e:2+0,c:6|n:7,e:...
# 42   EnvironmentState(NetworkState(e:3+0,c:9|n:7,e:...
# 43   EnvironmentState(NetworkState(e:4+0,c:11|n:7,e...
# 44   EnvironmentState(NetworkState(e:5+0,c:13|n:7,e...
# 45   EnvironmentState(NetworkState(e:6+0,c:15|n:7,e...
# 46   EnvironmentState(NetworkState(e:6+0,c:15|n:7,e...
# 47   EnvironmentState(NetworkState(e:0+0,c:0|n:10,e...
# 48   EnvironmentState(NetworkState(e:0+1,c:0|n:10,e...
# 49   EnvironmentState(NetworkState(e:1+0,c:3|n:10,e...
# 50   EnvironmentState(NetworkState(e:1+1,c:3|n:10,e...
# 51   EnvironmentState(NetworkState(e:2+0,c:5|n:10,e...
# 52   EnvironmentState(NetworkState(e:2+1,c:5|n:10,e...
# 53   EnvironmentState(NetworkState(e:3+0,c:8|n:10,e...
# 54   EnvironmentState(NetworkState(e:3+1,c:8|n:10,e...
# 55   EnvironmentState(NetworkState(e:4+0,c:10|n:10,...
# 56   EnvironmentState(NetworkState(e:4+1,c:10|n:10,...
# 57   EnvironmentState(NetworkState(e:5+0,c:13|n:10,...
# 58   EnvironmentState(NetworkState(e:5+1,c:13|n:10,...
# 59   EnvironmentState(NetworkState(e:6+0,c:15|n:10,...
# 60   EnvironmentState(NetworkState(e:6+1,c:15|n:10,...
# 61   EnvironmentState(NetworkState(e:7+0,c:18|n:10,...
# 62   EnvironmentState(NetworkState(e:7+1,c:18|n:10,...
# 63   EnvironmentState(NetworkState(e:8+0,c:20|n:10,...
# 64   EnvironmentState(NetworkState(e:8+1,c:20|n:10,...
# 65   EnvironmentState(NetworkState(e:9+0,c:22|n:10,...
# 66   EnvironmentState(NetworkState(e:9+1,c:22|n:10,...
# 67   EnvironmentState(NetworkState(e:9+1,c:22|n:10,...
# 68   EnvironmentState(NetworkState(e:10+0,c:25|n:10...
# 69   EnvironmentState(NetworkState(e:10+1,c:25|n:10...
# 70   EnvironmentState(NetworkState(e:11+0,c:28|n:10...
# 71   EnvironmentState(NetworkState(e:11+1,c:28|n:10...
# 72   EnvironmentState(NetworkState(e:11+0,c:28|n:10...
# 73   EnvironmentState(NetworkState(e:11+1,c:28|n:10...
# 74   EnvironmentState(NetworkState(e:11+1,c:28|n:10...
# 75   EnvironmentState(NetworkState(e:12+0,c:31|n:10...
# 76   EnvironmentState(NetworkState(e:12+1,c:31|n:10...
# 77   EnvironmentState(NetworkState(e:13+0,c:35|n:10...
# 78   EnvironmentState(NetworkState(e:13+1,c:35|n:10...
# 79   EnvironmentState(NetworkState(e:13+0,c:35|n:10...
# 80   EnvironmentState(NetworkState(e:13+1,c:35|n:10...
# 81   EnvironmentState(NetworkState(e:14+0,c:38|n:10...
# 82   EnvironmentState(NetworkState(e:0+0,c:0|n:10,e...
# 83   EnvironmentState(NetworkState(e:0+0,c:0|n:10,e...
# 84   EnvironmentState(NetworkState(e:0+1,c:0|n:10,e...
# 85   EnvironmentState(NetworkState(e:1+0,c:2|n:10,e...
# 86   EnvironmentState(NetworkState(e:1+1,c:2|n:10,e...
# 87   EnvironmentState(NetworkState(e:2+0,c:4|n:10,e...
# 88   EnvironmentState(NetworkState(e:2+1,c:4|n:10,e...
# 89   EnvironmentState(NetworkState(e:3+0,c:6|n:10,e...
# 90   EnvironmentState(NetworkState(e:3+1,c:6|n:10,e...
# 91   EnvironmentState(NetworkState(e:4+0,c:9|n:10,e...
# 92   EnvironmentState(NetworkState(e:4+1,c:9|n:10,e...
# 93   EnvironmentState(NetworkState(e:5+0,c:12|n:10,...
# 94   EnvironmentState(NetworkState(e:5+1,c:12|n:10,...
# 95   EnvironmentState(NetworkState(e:6+0,c:14|n:10,...
# 96   EnvironmentState(NetworkState(e:6+1,c:14|n:10,...
# 97   EnvironmentState(NetworkState(e:7+0,c:17|n:10,...
# 98   EnvironmentState(NetworkState(e:7+1,c:17|n:10,...
# 99   EnvironmentState(NetworkState(e:8+0,c:19|n:10,...
# 100  EnvironmentState(NetworkState(e:8+1,c:19|n:10,...
# 101  EnvironmentState(NetworkState(e:9+0,c:22|n:10,...
# 102  EnvironmentState(NetworkState(e:9+1,c:22|n:10,...
# 103  EnvironmentState(NetworkState(e:10+0,c:25|n:10...
# 104  EnvironmentState(NetworkState(e:10+1,c:25|n:10...
# 105  EnvironmentState(NetworkState(e:11+0,c:29|n:10...
# 106  EnvironmentState(NetworkState(e:0+0,c:0|n:10,e...
# 107  EnvironmentState(NetworkState(e:0+1,c:0|n:10,e...
# 108  EnvironmentState(NetworkState(e:1+0,c:2|n:10,e...
# 109  EnvironmentState(NetworkState(e:1+1,c:2|n:10,e...
# 110  EnvironmentState(NetworkState(e:2+0,c:5|n:10,e...
# 111  EnvironmentState(NetworkState(e:2+1,c:5|n:10,e...
# 112  EnvironmentState(NetworkState(e:3+0,c:7|n:10,e...
# 113  EnvironmentState(NetworkState(e:3+1,c:7|n:10,e...
# 114  EnvironmentState(NetworkState(e:4+0,c:9|n:10,e...
# 115  EnvironmentState(NetworkState(e:4+1,c:9|n:10,e...
# 116  EnvironmentState(NetworkState(e:5+0,c:11|n:10,...
# 117  EnvironmentState(NetworkState(e:5+1,c:11|n:10,...
# 118  EnvironmentState(NetworkState(e:6+0,c:14|n:10,...
# 119  EnvironmentState(NetworkState(e:6+1,c:14|n:10,...
# 120  EnvironmentState(NetworkState(e:7+0,c:16|n:10,...
# 121  EnvironmentState(NetworkState(e:7+1,c:16|n:10,...
# 122  EnvironmentState(NetworkState(e:8+0,c:19|n:10,...
# 123  EnvironmentState(NetworkState(e:8+1,c:19|n:10,...
# 124  EnvironmentState(NetworkState(e:9+0,c:22|n:10,...
# 125  EnvironmentState(NetworkState(e:9+1,c:22|n:10,...
# 126  EnvironmentState(NetworkState(e:10+0,c:26|n:10...
# 127  EnvironmentState(NetworkState(e:10+1,c:26|n:10...
# 128  EnvironmentState(NetworkState(e:11+0,c:29|n:10...
# 129  EnvironmentState(NetworkState(e:0+0,c:0|n:10,e...
# 130  EnvironmentState(NetworkState(e:0+0,c:0|n:10,e...
# 131  EnvironmentState(NetworkState(e:0+1,c:0|n:10,e...
# 132  EnvironmentState(NetworkState(e:1+0,c:2|n:10,e...
# 133  EnvironmentState(NetworkState(e:1+1,c:2|n:10,e...
# 134  EnvironmentState(NetworkState(e:2+0,c:4|n:10,e...
# 135  EnvironmentState(NetworkState(e:2+1,c:4|n:10,e...
# 136  EnvironmentState(NetworkState(e:3+0,c:6|n:10,e...
# 137  EnvironmentState(NetworkState(e:3+1,c:6|n:10,e...
# 138  EnvironmentState(NetworkState(e:4+0,c:8|n:10,e...
# 139  EnvironmentState(NetworkState(e:4+1,c:8|n:10,e...
# 140  EnvironmentState(NetworkState(e:5+0,c:11|n:10,...
# 141  EnvironmentState(NetworkState(e:5+1,c:11|n:10,...
# 142  EnvironmentState(NetworkState(e:6+0,c:13|n:10,...
# 143  EnvironmentState(NetworkState(e:6+1,c:13|n:10,...
# 144  EnvironmentState(NetworkState(e:7+0,c:16|n:10,...
# 145  EnvironmentState(NetworkState(e:7+1,c:16|n:10,...
# 146  EnvironmentState(NetworkState(e:8+0,c:19|n:10,...
# 147  EnvironmentState(NetworkState(e:8+1,c:19|n:10,...
# 148  EnvironmentState(NetworkState(e:9+0,c:23|n:10,...
# 149  EnvironmentState(NetworkState(e:9+1,c:23|n:10,...
# 150  EnvironmentState(NetworkState(e:10+0,c:26|n:10...
# 151  EnvironmentState(NetworkState(e:10+1,c:26|n:10...
# 152  EnvironmentState(NetworkState(e:11+0,c:29|n:10...
# 153  EnvironmentState(NetworkState(e:11+1,c:29|n:10...
# 154  EnvironmentState(NetworkState(e:12+0,c:32|n:10...
# 155  EnvironmentState(NetworkState(e:12+1,c:32|n:10...
# 156  EnvironmentState(NetworkState(e:0+0,c:0|n:10,e...
# 157  EnvironmentState(NetworkState(e:0+1,c:0|n:10,e...
# 158  EnvironmentState(NetworkState(e:0+0,c:0|n:10,e...
# 159  EnvironmentState(NetworkState(e:0+1,c:0|n:10,e...
# 160  EnvironmentState(NetworkState(e:1+0,c:3|n:10,e...
# 161  EnvironmentState(NetworkState(e:1+1,c:3|n:10,e...
# 162  EnvironmentState(NetworkState(e:1+0,c:3|n:10,e...
# 163  EnvironmentState(NetworkState(e:1+1,c:3|n:10,e...
# 164  EnvironmentState(NetworkState(e:1+1,c:3|n:10,e...
# 165  EnvironmentState(NetworkState(e:2+0,c:6|n:10,e...
# 166  EnvironmentState(NetworkState(e:2+1,c:6|n:10,e...
# 167  EnvironmentState(NetworkState(e:2+1,c:6|n:10,e...
# 168  EnvironmentState(NetworkState(e:3+0,c:9|n:10,e...
# 169  EnvironmentState(NetworkState(e:3+1,c:9|n:10,e...
# 170  EnvironmentState(NetworkState(e:4+0,c:12|n:10,...
# 171  EnvironmentState(NetworkState(e:4+1,c:12|n:10,...
# 172  EnvironmentState(NetworkState(e:5+0,c:19|n:10,...
# 173  EnvironmentState(NetworkState(e:5+1,c:19|n:10,...
# 174  EnvironmentState(NetworkState(e:6+0,c:22|n:10,...
# 175  EnvironmentState(NetworkState(e:6+1,c:22|n:10,...
# 176  EnvironmentState(NetworkState(e:7+0,c:27|n:10,...
# 177  EnvironmentState(NetworkState(e:7+1,c:27|n:10,...
# 178  EnvironmentState(NetworkState(e:8+0,c:32|n:10,...
# 179  EnvironmentState(NetworkState(e:8+1,c:32|n:10,...
# 180  EnvironmentState(NetworkState(e:9+0,c:37|n:10,...
# 181  EnvironmentState(NetworkState(e:9+1,c:37|n:10,...
# 182  EnvironmentState(NetworkState(e:9+1,c:37|n:10,...
# 183  EnvironmentState(NetworkState(e:9+0,c:37|n:10,...
# 184  EnvironmentState(NetworkState(e:9+1,c:37|n:10,...
# 185  EnvironmentState(NetworkState(e:10+0,c:42|n:10...
# 186  EnvironmentState(NetworkState(e:0+0,c:0|n:10,e...
# 187  EnvironmentState(NetworkState(e:0+0,c:0|n:10,e...
# 188  EnvironmentState(NetworkState(e:0+1,c:0|n:10,e...
# 189  EnvironmentState(NetworkState(e:1+0,c:3|n:10,e...
# 190  EnvironmentState(NetworkState(e:1+1,c:3|n:10,e...
# 191  EnvironmentState(NetworkState(e:1+1,c:3|n:10,e...
# 192  EnvironmentState(NetworkState(e:2+0,c:8|n:10,e...
# 193  EnvironmentState(NetworkState(e:2+1,c:8|n:10,e...
# 194  EnvironmentState(NetworkState(e:2+1,c:8|n:10,e...
# 195  EnvironmentState(NetworkState(e:3+0,c:11|n:10,...
# 196  EnvironmentState(NetworkState(e:3+1,c:11|n:10,...
# 197  EnvironmentState(NetworkState(e:4+0,c:16|n:10,...
# 198  EnvironmentState(NetworkState(e:4+1,c:16|n:10,...
# 199  EnvironmentState(NetworkState(e:4+0,c:16|n:10,...
# 200  EnvironmentState(NetworkState(e:4+1,c:16|n:10,...
# 201  EnvironmentState(NetworkState(e:4+1,c:16|n:10,...
# 202  EnvironmentState(NetworkState(e:5+0,c:19|n:10,...
# 203  EnvironmentState(NetworkState(e:5+1,c:19|n:10,...
# 204  EnvironmentState(NetworkState(e:5+1,c:19|n:10,...
# 205  EnvironmentState(NetworkState(e:6+0,c:22|n:10,...
# 206  EnvironmentState(NetworkState(e:6+1,c:22|n:10,...
# 207  EnvironmentState(NetworkState(e:7+0,c:25|n:10,...
# 208  EnvironmentState(NetworkState(e:7+1,c:25|n:10,...
# 209  EnvironmentState(NetworkState(e:7+0,c:25|n:10,...
# 210  EnvironmentState(NetworkState(e:7+1,c:25|n:10,...
# 211  EnvironmentState(NetworkState(e:8+0,c:30|n:10,...
# 212  EnvironmentState(NetworkState(e:8+1,c:30|n:10,...
# 213  EnvironmentState(NetworkState(e:9+0,c:37|n:10,...
# 214  EnvironmentState(NetworkState(e:9+1,c:37|n:10,...
# 215  EnvironmentState(NetworkState(e:9+1,c:37|n:10,...
# 216  EnvironmentState(NetworkState(e:9+0,c:37|n:10,...
# 217  EnvironmentState(NetworkState(e:9+1,c:37|n:10,...
# 218  EnvironmentState(NetworkState(e:10+0,c:42|n:10...
# 219  EnvironmentState(NetworkState(e:10+1,c:42|n:10...
# 220  EnvironmentState(NetworkState(e:11+0,c:47|n:10...
# 221  EnvironmentState(NetworkState(e:0+0,c:0|n:10,e...
# 222  EnvironmentState(NetworkState(e:0+1,c:0|n:10,e...
# 223  EnvironmentState(NetworkState(e:1+0,c:3|n:10,e...
# 224  EnvironmentState(NetworkState(e:1+1,c:3|n:10,e...
# 225  EnvironmentState(NetworkState(e:2+0,c:8|n:10,e...
# 226  EnvironmentState(NetworkState(e:2+1,c:8|n:10,e...
# 227  EnvironmentState(NetworkState(e:3+0,c:11|n:10,...
# 228  EnvironmentState(NetworkState(e:3+1,c:11|n:10,...
# 229  EnvironmentState(NetworkState(e:4+0,c:16|n:10,...
# 230  EnvironmentState(NetworkState(e:4+1,c:16|n:10,...
# 231  EnvironmentState(NetworkState(e:5+0,c:21|n:10,...
# 232  EnvironmentState(NetworkState(e:5+1,c:21|n:10,...
# 233  EnvironmentState(NetworkState(e:6+0,c:24|n:10,...
# 234  EnvironmentState(NetworkState(e:6+1,c:24|n:10,...
# 235  EnvironmentState(NetworkState(e:7+0,c:29|n:10,...
# 236  EnvironmentState(NetworkState(e:7+1,c:29|n:10,...
# 237  EnvironmentState(NetworkState(e:7+0,c:29|n:10,...
# 238  EnvironmentState(NetworkState(e:7+1,c:29|n:10,...
# 239  EnvironmentState(NetworkState(e:8+0,c:32|n:10,...
# 240  EnvironmentState(NetworkState(e:8+1,c:32|n:10,...
# 241  EnvironmentState(NetworkState(e:8+0,c:32|n:10,...
# 242  EnvironmentState(NetworkState(e:8+1,c:32|n:10,...
# 243  EnvironmentState(NetworkState(e:9+0,c:35|n:10,...
# 244  EnvironmentState(NetworkState(e:9+1,c:35|n:10,...
# 245  EnvironmentState(NetworkState(e:9+0,c:35|n:10,...
# 246  EnvironmentState(NetworkState(e:0+0,c:0|n:7,e:...
# 247  EnvironmentState(NetworkState(e:1+0,c:3|n:7,e:...
# 248  EnvironmentState(NetworkState(e:2+0,c:6|n:7,e:...
# 249  EnvironmentState(NetworkState(e:3+0,c:9|n:7,e:...
# 250  EnvironmentState(NetworkState(e:4+0,c:11|n:7,e...
# 251  EnvironmentState(NetworkState(e:5+0,c:13|n:7,e...
# 252  EnvironmentState(NetworkState(e:6+0,c:15|n:7,e...
# 253  EnvironmentState(NetworkState(e:6+0,c:15|n:7,e...
# 254  EnvironmentState(NetworkState(e:0+0,c:0|n:7,e:...
# 255  EnvironmentState(NetworkState(e:1+0,c:4|n:7,e:...
# 256  EnvironmentState(NetworkState(e:2+0,c:8|n:7,e:...
# 257  EnvironmentState(NetworkState(e:3+0,c:12|n:7,e...
# 258  EnvironmentState(NetworkState(e:4+0,c:18|n:7,e...
# 259  EnvironmentState(NetworkState(e:5+0,c:24|n:7,e...
# 260  EnvironmentState(NetworkState(e:6+0,c:30|n:7,e...
# 261  EnvironmentState(NetworkState(e:6+0,c:30|n:7,e...
# 262  EnvironmentState(NetworkState(e:0+0,c:0|n:7,e:...
# 263  EnvironmentState(NetworkState(e:1+0,c:4|n:7,e:...
# 264  EnvironmentState(NetworkState(e:2+0,c:8|n:7,e:...
# 265  EnvironmentState(NetworkState(e:3+0,c:12|n:7,e...
# 266  EnvironmentState(NetworkState(e:4+0,c:15|n:7,e...
# 267  EnvironmentState(NetworkState(e:5+0,c:18|n:7,e...
# 268  EnvironmentState(NetworkState(e:6+0,c:21|n:7,e...
# 269  EnvironmentState(NetworkState(e:6+0,c:21|n:7,e...
# 270  EnvironmentState(NetworkState(e:0+0,c:0|n:7,e:...
# 271  EnvironmentState(NetworkState(e:1+0,c:7|n:7,e:...
# 272  EnvironmentState(NetworkState(e:2+0,c:14|n:7,e...
# 273  EnvironmentState(NetworkState(e:3+0,c:21|n:7,e...
# 274  EnvironmentState(NetworkState(e:4+0,c:29|n:7,e...
# 275  EnvironmentState(NetworkState(e:5+0,c:37|n:7,e...
# 276  EnvironmentState(NetworkState(e:6+0,c:45|n:7,e...
# 277  EnvironmentState(NetworkState(e:6+0,c:45|n:7,e...
# 278  EnvironmentState(NetworkState(e:0+0,c:0|n:7,e:...
# 279  EnvironmentState(NetworkState(e:1+0,c:3|n:7,e:...
# 280  EnvironmentState(NetworkState(e:2+0,c:5|n:7,e:...
# 281  EnvironmentState(NetworkState(e:3+0,c:7|n:7,e:...
# 282  EnvironmentState(NetworkState(e:4+0,c:10|n:7,e...
# 283  EnvironmentState(NetworkState(e:5+0,c:14|n:7,e...
# 284  EnvironmentState(NetworkState(e:6+0,c:16|n:7,e...
# 285  EnvironmentState(NetworkState(e:6+0,c:16|n:7,e...

# %%
for index,row in df.iterrows():
    break

# %% [markdown]
# # Storing processed tables into a dictionary

# %%
processed_tables = {}
for key, df in tables.items():
    df = df.copy()
    df = construct_state_from_table(df, state_name='next_state')
    df = construct_state_from_table(df, state_name='state')

    processed_tables[key] = df
    print('Processed', key)
# Out:
# Processed 7
# Processed 3
# Processed 2
# Processed 6
# Processed 5
# Processed 4
# Processed 1
# Processed 9
# Processed 10

# %% [markdown]
# # Export processed tables

# %%
# with processed_tables_pickle_file.open('wb') as handle:
#     pickle.dump(processed_tables, handle, protocol=pickle.HIGHEST_PROTOCOL)

# print('Saved processed tables to {}'.format(processed_tables_pickle_file))

# %% [markdown]
# # Construct state transition lists per world.

# %%
transitions = dict()

for student_no, log_df in processed_tables.items():
    transitions[student_no] = dict()

    for name in world_renamer:

        df = log_df[log_df['header.frame_id'] == name].reset_index()

        trans_list = []
        for i, row in df.iterrows():
            if i == 0:
                trans_list.append(row['state'])
            trans_list.append(row['action'])
            trans_list.append(row['next_state'])

        if len(trans_list) != 0:
            print('Added {} states for {} at {}'.format(
                len(trans_list)+1//2, student_no, name))
            transitions[student_no][world_renamer[name]] = trans_list
# Out:
# Added 41 states for 7 at pretest-1
# Added 17 states for 7 at pretest-2
# Added 13 states for 7 at pretest-3
# Added 9 states for 7 at pretest-4
# Added 11 states for 7 at pretest-5
# Added 11 states for 7 at posttest-1
# Added 7 states for 7 at posttest-2
# Added 9 states for 7 at posttest-3
# Added 7 states for 7 at posttest-4
# Added 11 states for 7 at posttest-5
# Added 175 states for 7 at collab-activity-2
# Added 9 states for 7 at indiv-illustrate
# Added 95 states for 7 at collab-activity
# Added 17 states for 3 at pretest-1
# Added 17 states for 3 at pretest-2
# Added 17 states for 3 at pretest-3
# Added 31 states for 3 at pretest-4
# Added 17 states for 3 at pretest-5
# Added 17 states for 3 at posttest-1
# Added 17 states for 3 at posttest-2
# Added 17 states for 3 at posttest-3
# Added 17 states for 3 at posttest-4
# Added 17 states for 3 at posttest-5
# Added 199 states for 3 at collab-activity-2
# Added 9 states for 3 at indiv-illustrate
# Added 163 states for 3 at collab-activity
# Added 7 states for 2 at pretest-1
# Added 39 states for 2 at pretest-2
# Added 19 states for 2 at pretest-3
# Added 37 states for 2 at pretest-4
# Added 21 states for 2 at pretest-5
# Added 21 states for 2 at posttest-1
# Added 17 states for 2 at posttest-2
# Added 17 states for 2 at posttest-3
# Added 17 states for 2 at posttest-4
# Added 19 states for 2 at posttest-5
# Added 123 states for 2 at collab-activity-2
# Added 9 states for 2 at indiv-illustrate
# Added 111 states for 2 at collab-activity
# Added 19 states for 6 at pretest-1
# Added 21 states for 6 at pretest-2
# Added 19 states for 6 at pretest-3
# Added 19 states for 6 at pretest-4
# Added 19 states for 6 at pretest-5
# Added 17 states for 6 at posttest-1
# Added 19 states for 6 at posttest-2
# Added 19 states for 6 at posttest-3
# Added 19 states for 6 at posttest-4
# Added 17 states for 6 at posttest-5
# Added 175 states for 6 at collab-activity-2
# Added 9 states for 6 at indiv-illustrate
# Added 209 states for 6 at collab-activity
# Added 39 states for 5 at pretest-1
# Added 19 states for 5 at pretest-2
# Added 19 states for 5 at pretest-3
# Added 33 states for 5 at pretest-4
# Added 19 states for 5 at pretest-5
# Added 21 states for 5 at posttest-1
# Added 17 states for 5 at posttest-2
# Added 21 states for 5 at posttest-3
# Added 19 states for 5 at posttest-4
# Added 35 states for 5 at posttest-5
# Added 75 states for 5 at collab-activity-2
# Added 9 states for 5 at indiv-illustrate
# Added 277 states for 5 at collab-activity
# Added 9 states for 4 at pretest-1
# Added 27 states for 4 at pretest-2
# Added 17 states for 4 at pretest-3
# Added 17 states for 4 at pretest-4
# Added 17 states for 4 at pretest-5
# Added 19 states for 4 at posttest-1
# Added 23 states for 4 at posttest-2
# Added 23 states for 4 at posttest-3
# Added 21 states for 4 at posttest-4
# Added 19 states for 4 at posttest-5
# Added 151 states for 4 at collab-activity-2
# Added 9 states for 4 at indiv-illustrate
# Added 271 states for 4 at collab-activity
# Added 19 states for 1 at pretest-1
# Added 19 states for 1 at pretest-2
# Added 19 states for 1 at pretest-3
# Added 17 states for 1 at pretest-4
# Added 17 states for 1 at pretest-5
# Added 17 states for 1 at posttest-1
# Added 17 states for 1 at posttest-2
# Added 17 states for 1 at posttest-3
# Added 17 states for 1 at posttest-4
# Added 17 states for 1 at posttest-5
# Added 181 states for 1 at collab-activity-2
# Added 9 states for 1 at indiv-illustrate
# Added 219 states for 1 at collab-activity
# Added 25 states for 9 at pretest-1
# Added 29 states for 9 at pretest-2
# Added 33 states for 9 at pretest-3
# Added 29 states for 9 at pretest-4
# Added 19 states for 9 at pretest-5
# Added 17 states for 9 at posttest-1
# Added 19 states for 9 at posttest-2
# Added 17 states for 9 at posttest-3
# Added 17 states for 9 at posttest-4
# Added 17 states for 9 at posttest-5
# Added 111 states for 9 at collab-activity-2
# Added 9 states for 9 at indiv-illustrate
# Added 261 states for 9 at collab-activity
# Added 17 states for 10 at pretest-1
# Added 57 states for 10 at pretest-2
# Added 17 states for 10 at pretest-3
# Added 17 states for 10 at pretest-4
# Added 17 states for 10 at pretest-5
# Added 17 states for 10 at posttest-1
# Added 21 states for 10 at posttest-2
# Added 17 states for 10 at posttest-3
# Added 17 states for 10 at posttest-4
# Added 17 states for 10 at posttest-5
# Added 53 states for 10 at collab-activity-2
# Added 9 states for 10 at indiv-illustrate
# Added 69 states for 10 at collab-activity

# %% [markdown]
# # Export transition lists

# %%
transitions[1]['pretest-1']
# Out:
# [EnvironmentState(NetworkState(e:0+0,c:0|n:7,e:12;s:0)@1/inf,a:H;p:0,t:0,s:0,h:0),
#  Action(pick(7,0),Human),
#  EnvironmentState(NetworkState(e:1+0,c:4|n:7,e:12;s:0)@1/inf,a:H;p:0,t:0,s:0,h:0),
#  Action(pick(0,3),Human),
#  EnvironmentState(NetworkState(e:2+0,c:7|n:7,e:12;s:0)@1/inf,a:H;p:0,t:0,s:0,h:0),
#  Action(pick(3,5),Human),
#  EnvironmentState(NetworkState(e:3+0,c:11|n:7,e:12;s:0)@1/inf,a:H;p:0,t:0,s:0,h:0),
#  Action(pick(7,5),Human),
#  EnvironmentState(NetworkState(e:4+0,c:14|n:7,e:12;s:0)@1/inf,a:H;p:0,t:0,s:0,h:0),
#  Action(pick(5,4),Human),
#  EnvironmentState(NetworkState(e:5+0,c:16|n:7,e:12;s:0)@1/inf,a:H;p:0,t:0,s:0,h:0),
#  Action(pick(4,1),Human),
#  EnvironmentState(NetworkState(e:6+0,c:19|n:7,e:12;s:0)@1/inf,a:H;p:0,t:0,s:0,h:0),
#  Action(pick(5,6),Human),
#  EnvironmentState(NetworkState(e:7+0,c:23|n:7,e:12;s:1)@1/inf,a:H;p:0,t:0,s:0,h:0),
#  Action(attempt-submit,Human),
#  EnvironmentState(NetworkState(e:7+0,c:23|n:7,e:12;s:1)@2/inf,a:H;p:0,t:0,s:1,h:0),
#  Action(attempt-submit,Human),
#  EnvironmentState(NetworkState(e:7+0,c:23|n:7,e:12;s:1)@3/inf,a:H;p:0,t:1,s:1,h:0)]

# %%
with transitions_pickle_file.open('wb') as handle:
    pickle.dump(transitions, handle, protocol=pickle.HIGHEST_PROTOCOL)

print('Saved transition lists to {}'.format(transitions_pickle_file))
# Out:
# Saved transition lists to ../processed_data/justhink_spring21_transition_logs.pickle
